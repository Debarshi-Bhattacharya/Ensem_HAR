# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + 'C:/Users/bhatt/Desktop/Research_work/Dataset/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + 'C:/Users/bhatt/Desktop/Research_work/Dataset/UCI HAR Dataset/')
    
    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.merge import concatenate

# %%
class cnn:
    
    def __init__(self,n_timesteps,n_features,n_outputs):
        self.n_timesteps=n_timesteps
        self.n_features=n_features
        self.n_outputs=n_outputs
        ##Level_1
        # layer 1
        inputs1_1= Input(shape=(n_timesteps,n_features))##128,9
        conv1_1 = Conv1D(filters=128, kernel_size=3, activation='relu')(inputs1_1) ##none,126,128
            # layer 2
        inputs1_2= Input(shape=(n_timesteps,n_features))
        conv1_2 = Conv1D(filters=128, kernel_size=5, activation='relu')(inputs1_2)##124,128
            # layer 3
        inputs1_3= Input(shape=(n_timesteps,n_features))
        conv1_3 = Conv1D(filters=128, kernel_size=7, activation='relu')(inputs1_3)##122,128
            # layer 4
        inputs1_4= Input(shape=(n_timesteps,n_features))
        conv1_4 = Conv1D(filters=128, kernel_size=9, activation='relu')(inputs1_4)##120,128

            # merge1
        merged_1 = concatenate([conv1_1,conv1_2,conv1_3,conv1_4],axis=1)

            #maxpool1
        pool_1=MaxPooling1D(pool_size=5)(merged_1)
        ##Level_2
        # layer 1
        conv2_1 = Conv1D(filters=64, kernel_size=3, activation='relu')(pool_1)
        # layer 2
        conv2_2 = Conv1D(filters=64, kernel_size=5, activation='relu')(pool_1)
        # layer 3
        conv2_3 = Conv1D(filters=64, kernel_size=7, activation='relu')(pool_1)
        # layer 4

        conv2_4 = Conv1D(filters=64, kernel_size=9, activation='relu')(pool_1) 
        # merge2
        merged_2 = concatenate([conv2_1,conv2_2,conv2_3,conv2_4],axis=1)

        #maxpool2
        pool_2=MaxPooling1D(pool_size=5)(merged_2)


        ##Level_3
        # layer 1
        conv3_1 = Conv1D(filters=32, kernel_size=3, activation='relu')(pool_2)
        # layer 2
        conv3_2 = Conv1D(filters=32, kernel_size=5, activation='relu')(pool_2)
        # layer 3
        conv3_3 = Conv1D(filters=32, kernel_size=7, activation='relu')(pool_2)
        # layer 4

        conv3_4 = Conv1D(filters=32, kernel_size=9, activation='relu')(pool_2) 
        # merge2
        merged_3 = concatenate([conv3_1,conv3_2,conv3_3,conv3_4],axis=1)

        #maxpool2
        pool_3=MaxPooling1D(pool_size=5)(merged_3)


        #flatten
        flat_cnn=Flatten()(pool_3)
        
        ##dense layer
        dense = Dense(512, activation='relu')(flat_cnn)
        outputs = Dense(n_outputs, activation='softmax')(dense)
        
        ##MODEL
        self.cnn2_model = Model([inputs1_1, inputs1_2, inputs1_3,inputs1_4], outputs)
        
    def do_compile(self,trainx,testX,trainy_one_hot,testy_one_hot):
        self.cnn2_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        self.cnn2_model.summary()
        # fit network
        model_history=self.cnn2_model.fit(x=[trainX,trainX,trainX,trainX], y=trainy_one_hot, epochs=30, batch_size=32,validation_data= ([testX,testX,testX,testX],testy_one_hot))
        
    
    def prediction(self,testX):
        predy=self.cnn2_model.predict([testX,testX,testX,testX])
        predy=np.argmax(predy, axis=-1)
        return predy

# %%
cnn_model=cnn(n_timesteps,n_features,n_outputs)
cnn_model.do_compile(trainX,testX,trainy_one_hot,testy_one_hot)

pred=cnn_model.prediction(testX)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 126, 128)     3584        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 124, 128)     5888        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 122, 128)     8192        input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 120, 128)     10496       input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 492, 128)     0           conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 98, 128)      0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 96, 64)       24640       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 94, 64)       41024       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 92, 64)       57408       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 90, 64)       73792       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 372, 64)      0           conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 74, 64)       0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 72, 32)       6176        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 70, 32)       10272       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 68, 32)       14368       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 66, 32)       18464       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 276, 32)      0           conv1d_20[0][0]
#                                                                  conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 55, 32)       0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1760)         0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          901632      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            3078        dense_2[0][0]
# ==================================================================================================
# Total params: 1,179,014
# Trainable params: 1,179,014
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 230/230 [==============================] - 70s 166ms/step - loss: 0.5113 - accuracy: 0.8005 - val_loss: 0.2022 - val_accuracy: 0.9233
# Epoch 2/30
# 230/230 [==============================] - 26s 113ms/step - loss: 0.1110 - accuracy: 0.9555 - val_loss: 0.3077 - val_accuracy: 0.9026
# Epoch 3/30
# 230/230 [==============================] - 26s 115ms/step - loss: 0.1194 - accuracy: 0.9520 - val_loss: 0.1786 - val_accuracy: 0.9298
# Epoch 4/30
# 230/230 [==============================] - 23s 102ms/step - loss: 0.0995 - accuracy: 0.9547 - val_loss: 0.2020 - val_accuracy: 0.9308
# Epoch 5/30
# 230/230 [==============================] - 27s 118ms/step - loss: 0.0946 - accuracy: 0.9585 - val_loss: 0.1851 - val_accuracy: 0.9427
# Epoch 6/30
# 230/230 [==============================] - 29s 128ms/step - loss: 0.1058 - accuracy: 0.9557 - val_loss: 0.2705 - val_accuracy: 0.9240
# Epoch 7/30
# 230/230 [==============================] - 28s 123ms/step - loss: 0.0839 - accuracy: 0.9607 - val_loss: 0.2558 - val_accuracy: 0.9108
# Epoch 8/30
# 230/230 [==============================] - 32s 140ms/step - loss: 0.0729 - accuracy: 0.9655 - val_loss: 0.3271 - val_accuracy: 0.9250
# Epoch 9/30
# 230/230 [==============================] - 26s 101ms/step - loss: 0.0759 - accuracy: 0.9636 - val_loss: 0.3168 - val_accuracy: 0.9196
# Epoch 10/30
# 230/230 [==============================] - 28s 123ms/step - loss: 0.0624 - accuracy: 0.9705 - val_loss: 0.2946 - val_accuracy: 0.9318
# Epoch 11/30
# 230/230 [==============================] - 28s 121ms/step - loss: 0.0935 - accuracy: 0.9618 - val_loss: 0.2474 - val_accuracy: 0.9352
# Epoch 12/30
# 230/230 [==============================] - 28s 122ms/step - loss: 0.0525 - accuracy: 0.9745 - val_loss: 0.3328 - val_accuracy: 0.9253
# Epoch 13/30
# 230/230 [==============================] - 31s 136ms/step - loss: 0.0618 - accuracy: 0.9730 - val_loss: 0.3465 - val_accuracy: 0.9260
# Epoch 14/30
# 230/230 [==============================] - 28s 122ms/step - loss: 0.0675 - accuracy: 0.9725 - val_loss: 0.2525 - val_accuracy: 0.9430
# Epoch 15/30
# 230/230 [==============================] - 33s 145ms/step - loss: 0.0351 - accuracy: 0.9855 - val_loss: 0.2642 - val_accuracy: 0.9413
# Epoch 16/30
# 230/230 [==============================] - 28s 123ms/step - loss: 0.0389 - accuracy: 0.9846 - val_loss: 0.3415 - val_accuracy: 0.9433
# Epoch 17/30
# 230/230 [==============================] - 27s 120ms/step - loss: 0.0391 - accuracy: 0.9827 - val_loss: 0.2941 - val_accuracy: 0.9369
# Epoch 18/30
# 230/230 [==============================] - 29s 125ms/step - loss: 0.0286 - accuracy: 0.9873 - val_loss: 0.4940 - val_accuracy: 0.9365
# Epoch 19/30
# 230/230 [==============================] - 31s 137ms/step - loss: 0.0404 - accuracy: 0.9845 - val_loss: 0.5182 - val_accuracy: 0.9175
# Epoch 20/30
# 230/230 [==============================] - 27s 117ms/step - loss: 0.0471 - accuracy: 0.9827 - val_loss: 0.3390 - val_accuracy: 0.9416
# Epoch 21/30
# 230/230 [==============================] - 33s 144ms/step - loss: 0.0306 - accuracy: 0.9879 - val_loss: 0.4453 - val_accuracy: 0.9179
# Epoch 22/30
# 230/230 [==============================] - 34s 146ms/step - loss: 0.0543 - accuracy: 0.9834 - val_loss: 0.5271 - val_accuracy: 0.9315
# Epoch 23/30
# 230/230 [==============================] - 32s 139ms/step - loss: 0.0249 - accuracy: 0.9875 - val_loss: 0.5263 - val_accuracy: 0.9369
# Epoch 24/30
# 230/230 [==============================] - 28s 122ms/step - loss: 0.0207 - accuracy: 0.9919 - val_loss: 0.5558 - val_accuracy: 0.9355
# Epoch 25/30
# 230/230 [==============================] - 35s 153ms/step - loss: 0.0184 - accuracy: 0.9932 - val_loss: 0.6743 - val_accuracy: 0.9196
# Epoch 26/30
# 230/230 [==============================] - 26s 115ms/step - loss: 0.0251 - accuracy: 0.9900 - val_loss: 0.7598 - val_accuracy: 0.9311
# Epoch 27/30
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0312 - accuracy: 0.9890 - val_loss: 0.4283 - val_accuracy: 0.9389
# Epoch 28/30
# 230/230 [==============================] - 26s 115ms/step - loss: 0.0244 - accuracy: 0.9904 - val_loss: 0.4775 - val_accuracy: 0.9359
# Epoch 29/30
# 230/230 [==============================] - 26s 115ms/step - loss: 0.0461 - accuracy: 0.9920 - val_loss: 0.3119 - val_accuracy: 0.9372
# Epoch 30/30
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0143 - accuracy: 0.9941 - val_loss: 0.2961 - val_accuracy: 0.9488

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
cm=confusion_matrix(testy,pred)
print(cm)
print(accuracy_score(testy,pred))
print(classification_report(testy,pred))
sns.heatmap(cm, annot=True)
# Out:
# [[463  24   8   1   0   0]
#  [  0 469   2   0   0   0]
#  [  0  11 409   0   0   0]
#  [  0   1   0 446  43   1]
#  [  0   0   0 105 427   0]
#  [  0   0   0   0   0 537]]
# 0.9334916864608076
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97       496
#            1       0.93      1.00      0.96       471
#            2       0.98      0.97      0.97       420
#            3       0.81      0.91      0.86       491
#            4       0.91      0.80      0.85       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.94      0.94      0.93      2947
# weighted avg       0.94      0.93      0.93      2947
# <AxesSubplot:>

# %%
cnn_model.cnn2_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 126, 128)     3584        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 124, 128)     5888        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 122, 128)     8192        input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 120, 128)     10496       input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 492, 128)     0           conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 98, 128)      0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 96, 64)       24640       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 94, 64)       41024       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 92, 64)       57408       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 90, 64)       73792       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 372, 64)      0           conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 74, 64)       0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 72, 32)       6176        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 70, 32)       10272       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 68, 32)       14368       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 66, 32)       18464       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 276, 32)      0           conv1d_20[0][0]
#                                                                  conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 55, 32)       0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1760)         0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          901632      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            3078        dense_2[0][0]
# ==================================================================================================
# Total params: 1,179,014
# Trainable params: 1,179,014
# Non-trainable params: 0
# __________________________________________________________________________________________________
